# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([[2, 3], [4, 1], [5, 2], [6, 5], [8, 7]])  # Features (X1, X2)
y = np.array([0, 1, 1, 1, 0])  # Binary target

# Best split found by the function
best_feature = 0  # Let's assume X1 gives the best split
best_threshold = 5.5  # Chosen threshold from our previous calculation

plt.figure(figsize=(6, 6))
for i, label in enumerate(np.unique(y)):
    plt.scatter(X[y == label, 0], X[y == label, 1], label=f"Class {label}")

# Plot decision boundary
plt.axvline(x=best_threshold, color='red', linestyle='--', label=f'Split at X1={best_threshold}')

plt.xlabel("Feature X1")
plt.ylabel("Feature X2")
plt.title("Decision Tree Best Split")
plt.legend()
plt.show()
